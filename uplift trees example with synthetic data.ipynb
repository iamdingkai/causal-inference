# %%
## for person study purposes
## Reference: https://causalml.readthedocs.io/en/latest/examples/uplift_trees_with_synthetic_data.html#

# %%
import numpy as np
import pandas as pd

from causalml.dataset import make_uplift_classification
from causalml.inference.tree import UpliftRandomForestClassifier
from causalml.metrics import plot_gain

from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 from causalml.dataset import make_uplift_classification
#       5 from causalml.inference.tree import UpliftRandomForestClassifier
#       6 from causalml.metrics import plot_gain
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/dataset/__init__.py:10
#       7 from .classification import make_uplift_classification
#       8 from .classification import make_uplift_classification_logistic
# ---> 10 from .synthetic import get_synthetic_preds, get_synthetic_preds_holdout
#      11 from .synthetic import get_synthetic_summary, get_synthetic_summary_holdout
#      12 from .synthetic import scatter_plot_summary, scatter_plot_summary_holdout
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/dataset/synthetic.py:12
#       9 from scipy.stats import entropy
#      10 import warnings
# ---> 12 from causalml.inference.meta import (
#      13     BaseXRegressor,
#      14     BaseRRegressor,
#      15     BaseSRegressor,
#      16     BaseTRegressor,
#      17 )
#      18 from causalml.inference.tree.causal.causaltree import CausalTreeRegressor
#      19 from causalml.propensity import ElasticNetPropensityModel
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/inference/meta/__init__.py:1
# ----> 1 from .slearner import LRSRegressor, BaseSLearner, BaseSRegressor, BaseSClassifier
#       2 from .tlearner import (
#       3     XGBTRegressor,
#       4     MLPTRegressor,
#    (...)
#       7     BaseTClassifier,
#       8 )
#       9 from .xlearner import BaseXLearner, BaseXRegressor, BaseXClassifier
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/inference/meta/slearner.py:9
#       6 import statsmodels.api as sm
#       7 from copy import deepcopy
# ----> 9 from causalml.inference.meta.base import BaseLearner
#      10 from causalml.inference.meta.utils import check_treatment_vector, convert_pd_to_np
#      11 from causalml.metrics import regression_metrics, classification_metrics
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/inference/meta/base.py:6
#       3 import numpy as np
#       4 import pandas as pd
# ----> 6 from causalml.inference.meta.explainer import Explainer
#       7 from causalml.inference.meta.utils import check_p_conditions, convert_pd_to_np
#       8 from causalml.propensity import compute_propensity_score
#
# File ~/anaconda3/lib/python3.10/site-packages/causalml/inference/meta/explainer.py:4
#       2 import shap
#       3 import matplotlib.pyplot as plt
# ----> 4 from lightgbm import LGBMRegressor
#       5 from sklearn.inspection import permutation_importance
#       6 from sklearn.model_selection import train_test_split
#
# File ~/anaconda3/lib/python3.10/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~/anaconda3/lib/python3.10/site-packages/lightgbm/basic.py:247
#     245     _LIB = Mock(ctypes.CDLL)  # type: ignore
#     246 else:
# --> 247     _LIB = _load_lib()
#     250 _NUMERIC_TYPES = (int, float, bool)
#     251 _ArrayLike = Union[List, np.ndarray, pd_Series]
#
# File ~/anaconda3/lib/python3.10/site-packages/lightgbm/basic.py:232, in _load_lib()
#     230 """Load LightGBM library."""
#     231 lib_path = find_lib_path()
# --> 232 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     233 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     234 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File ~/anaconda3/lib/python3.10/ctypes/__init__.py:452, in LibraryLoader.LoadLibrary(self, name)
#     451 def LoadLibrary(self, name):
# --> 452     return self._dlltype(name)
#
# File ~/anaconda3/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: dlopen(/Users/kai/anaconda3/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/kai/anaconda3/lib/python3.10/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
conda install lightgbm
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::scrapy==2.8.0=py310hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py310hecd8cb5_0
#   - defaults/osx-64::astroid==2.14.2=py310hecd8cb5_0
#   - defaults/osx-64::scikit-image==0.19.3=py310hcec6c5f_1
#   - defaults/osx-64::imbalanced-learn==0.10.1=py310hecd8cb5_0
#   - defaults/osx-64::twisted==22.2.0=py310hca72f7f_1
#   - conda-forge/noarch::python-lsp-server==1.7.2=pyhd8ed1ab_0
#   - defaults/osx-64::ipython==8.12.0=py310hecd8cb5_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::holoviews==1.15.4=py310hecd8cb5_0
#   - defaults/osx-64::qtconsole==5.4.2=py310hecd8cb5_0
#   - defaults/osx-64::typing-extensions==4.4.0=py310hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py310hecd8cb5_8
#   - defaults/osx-64::notebook==6.5.2=py310hecd8cb5_0
#   - defaults/osx-64::transformers==4.24.0=py310hecd8cb5_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::pydantic==1.10.2=py310hca72f7f_0
#   - defaults/osx-64::numpydoc==1.5.0=py310hecd8cb5_0
#   - defaults/osx-64::huggingface_hub==0.10.1=py310hecd8cb5_0
#   - defaults/osx-64::python-lsp-black==1.2.1=py310hecd8cb5_0
#   - defaults/osx-64::nbclassic==0.5.2=py310hecd8cb5_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/osx-64::panel==0.14.3=py310hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py310hecd8cb5_0
#   - defaults/osx-64::jupyterlab_server==2.19.0=py310hecd8cb5_0
#   - defaults/osx-64::hvplot==0.8.2=py310hecd8cb5_0
#   - defaults/osx-64::notebook-shim==0.2.2=py310hecd8cb5_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.23.4=py310hecd8cb5_0
#   - defaults/osx-64::jupyter_console==6.6.2=py310hecd8cb5_0
#   - defaults/osx-64::bokeh==2.4.3=py310hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.5.3=py310hecd8cb5_0
#   - defaults/osx-64::spyder-kernels==2.4.3=py310hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.19.2=py310h20db666_0
#   - defaults/osx-64::spyder==5.4.3=py310hecd8cb5_0
#   - defaults/osx-64::nbconvert==6.5.4=py310hecd8cb5_0
#   - defaults/osx-64::pylint==2.16.2=py310hecd8cb5_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::scrapy==2.8.0=py310hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py310hecd8cb5_0
#   - defaults/osx-64::astroid==2.14.2=py310hecd8cb5_0
#   - defaults/osx-64::scikit-image==0.19.3=py310hcec6c5f_1
#   - defaults/osx-64::imbalanced-learn==0.10.1=py310hecd8cb5_0
#   - defaults/osx-64::twisted==22.2.0=py310hca72f7f_1
#   - conda-forge/noarch::python-lsp-server==1.7.2=pyhd8ed1ab_0
#   - defaults/osx-64::ipython==8.12.0=py310hecd8cb5_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::holoviews==1.15.4=py310hecd8cb5_0
#   - defaults/osx-64::qtconsole==5.4.2=py310hecd8cb5_0
#   - defaults/osx-64::typing-extensions==4.4.0=py310hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py310hecd8cb5_8
#   - defaults/osx-64::notebook==6.5.2=py310hecd8cb5_0
#   - defaults/osx-64::transformers==4.24.0=py310hecd8cb5_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::pydantic==1.10.2=py310hca72f7f_0
#   - defaults/osx-64::numpydoc==1.5.0=py310hecd8cb5_0
#   - defaults/osx-64::huggingface_hub==0.10.1=py310hecd8cb5_0
#   - defaults/osx-64::python-lsp-black==1.2.1=py310hecd8cb5_0
#   - defaults/osx-64::nbclassic==0.5.2=py310hecd8cb5_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/osx-64::panel==0.14.3=py310hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py310hecd8cb5_0
#   - defaults/osx-64::jupyterlab_server==2.19.0=py310hecd8cb5_0
#   - defaults/osx-64::hvplot==0.8.2=py310hecd8cb5_0
#   - defaults/osx-64::notebook-shim==0.2.2=py310hecd8cb5_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.23.4=py310hecd8cb5_0
#   - defaults/osx-64::jupyter_console==6.6.2=py310hecd8cb5_0
#   - defaults/osx-64::bokeh==2.4.3=py310hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.5.3=py310hecd8cb5_0
#   - defaults/osx-64::spyder-kernels==2.4.3=py310hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.19.2=py310h20db666_0
#   - defaults/osx-64::spyder==5.4.3=py310hecd8cb5_0
#   - defaults/osx-64::nbconvert==6.5.4=py310hecd8cb5_0
#   - defaults/osx-64::pylint==2.16.2=py310hecd8cb5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kai/anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.3.11  |       hecd8cb5_0         128 KB
#     certifi-2024.2.2           |  py310hecd8cb5_0         160 KB
#     jupyter_client-7.4.9       |  py310hecd8cb5_0         215 KB
#     lightgbm-4.3.0             |  py310hcec6c5f_0         1.6 MB
#     networkx-3.1               |  py310hecd8cb5_0         2.8 MB
#     pygments-2.15.1            |  py310hecd8cb5_1         1.8 MB
#     pytorch-1.13.1             |cpu_py310h9e40b02_0        48.3 MB
#     scikit-learn-1.3.0         |  py310h3ea8b11_1         7.6 MB
#     ------------------------------------------------------------
#                                            Total:        62.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   lightgbm           pkgs/main/osx-64::lightgbm-4.3.0-py310hcec6c5f_0
#   networkx           pkgs/main/osx-64::networkx-3.1-py310hecd8cb5_0
#   pygments           pkgs/main/osx-64::pygments-2.15.1-py310hecd8cb5_1
#   pytorch            pkgs/main/osx-64::pytorch-1.13.1-cpu_py310h9e40b02_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-1.3.0-py310h3ea8b11_1
#   typing_extensions  pkgs/main/osx-64::typing_extensions-4.4.0-py310hecd8cb5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-hecd8cb5_0 --> 2024.3.11-hecd8cb5_0
#   certifi                          2023.5.7-py310hecd8cb5_0 --> 2024.2.2-py310hecd8cb5_0
#   openssl                                 1.1.1t-hca72f7f_0 --> 1.1.1w-hca72f7f_0
#
# The following packages will be DOWNGRADED:
#
#   jupyter_client                      8.1.0-py310hecd8cb5_0 --> 7.4.9-py310hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# lightgbm-4.3.0       | 1.6 MB    |                                       |   0%
# scikit-learn-1.3.0   | 7.6 MB    |                                       |   0%
#
# pygments-2.15.1      | 1.8 MB    |                                       |   0%
#
#
# certifi-2024.2.2     | 160 KB    |                                       |   0%
#
#
#
# ca-certificates-2024 | 128 KB    |                                       |   0%
#
#
#
#
# jupyter_client-7.4.9 | 215 KB    |                                       |   0%
#
#
#
#
#
# networkx-3.1         | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   |                                       |   0%
#
#
#
# ca-certificates-2024 | 128 KB    | ####6                                 |  12%
# scikit-learn-1.3.0   | 7.6 MB    |                                       |   0%
#
#
# certifi-2024.2.2     | 160 KB    | ###6                                  |  10%
#
# pygments-2.15.1      | 1.8 MB    | 3                                     |   1%
#
#
#
# lightgbm-4.3.0       | 1.6 MB    | 3                                     |   1%
# scikit-learn-1.3.0   | 7.6 MB    | ##                                    |   6%
#
#
# certifi-2024.2.2     | 160 KB    | ##################################### | 100%
#
#
#
#
# jupyter_client-7.4.9 | 215 KB    | ##7                                   |   7%
#
# pygments-2.15.1      | 1.8 MB    | #########1                            |  25%
#
#
#
#
#
# lightgbm-4.3.0       | 1.6 MB    | ##########2                           |  28%
# scikit-learn-1.3.0   | 7.6 MB    | #####2                                |  14%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   |                                       |   0%
#
#
#
#
# jupyter_client-7.4.9 | 215 KB    | ##################################### | 100%
#
#
#
#
# jupyter_client-7.4.9 | 215 KB    | ##################################### | 100%
#
# pygments-2.15.1      | 1.8 MB    | ##################6                   |  50%
#
#
#
#
#
# lightgbm-4.3.0       | 1.6 MB    | #####################1                |  57%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | 3                                     |   1%
# scikit-learn-1.3.0   | 7.6 MB    | ########8                             |  24%
#
# pygments-2.15.1      | 1.8 MB    | #########################7            |  70%
#
#
#
#
#
# lightgbm-4.3.0       | 1.6 MB    | ###############################       |  84%
# scikit-learn-1.3.0   | 7.6 MB    | ############                          |  33%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | 5                                     |   2%
#
#
#
#
#
# lightgbm-4.3.0       | 1.6 MB    | ##################################### | 100%
#
# pygments-2.15.1      | 1.8 MB    | ################################9     |  89%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | 8                                     |   2%
# scikit-learn-1.3.0   | 7.6 MB    | ################4                     |  44%
#
#
#
#
#
# networkx-3.1         | 2.8 MB    | #####################7                |  59%
# scikit-learn-1.3.0   | 7.6 MB    | #######################8              |  64%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #2                                    |   3%
#
#
#
#
#
# networkx-3.1         | 2.8 MB    | ###############################2      |  84%
# scikit-learn-1.3.0   | 7.6 MB    | ################################2     |  87%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #6                                    |   4%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##                                    |   6%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##5                                   |   7%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###                                   |   8%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###5                                  |  10%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ####1                                 |  11%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ####7                                 |  13%
#
# pygments-2.15.1      | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #####3                                |  14%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #####9                                |  16%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ######6                               |  18%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #######4                              |  20%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ########3                             |  23%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #########8                            |  27%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###########3                          |  31%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ############8                         |  35%
#
#
#
#
#
# networkx-3.1         | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##############1                       |  38%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###############5                      |  42%
# scikit-learn-1.3.0   | 7.6 MB    | ##################################### | 100%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ################8                     |  46%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##################                    |  49%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###################6                  |  53%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #####################3                |  58%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #######################2              |  63%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #########################1            |  68%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##########################7           |  72%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ############################6         |  77%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##############################4       |  82%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ################################1     |  87%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | #################################7    |  91%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ###################################3  |  96%
#
#
#
#
#
#
# pytorch-1.13.1       | 48.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: |
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.
